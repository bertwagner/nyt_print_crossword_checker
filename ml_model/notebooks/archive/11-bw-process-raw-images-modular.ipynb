# %%
# %load_ext autoreload
# %autoreload 2
from src.util import utilities as u

# %%
from src.data import image_proccessor as ip
import cv2
import datetime

image_name = '2021-12-05-bc29391e-94f2-431f-9a43-7ba999ca5275.png'
image_raw = cv2.imread(os.path.join("../data/raw/image_uploads",image_name))
date = datetime.datetime.strptime(image_name[0:10],'%Y-%m-%d').date()

processor = ip.ImageProcessor(image_raw)
processor.warp_and_transform()

u.showarray(processor.image['rgb'])
u.showarray(processor.image['warped'])

# %%
processor.slice_up_grid()
for cell in processor.image['cells'][:7]: # display only first several images
    u.showarray(cell)

# %%
from src.data import crossword_downloader as cd

downloader = cd.CrosswordDownloader()
answer_key = downloader.get_answer_key(date)
answer_key
# Out:
# ['C',
#  'B',
#  'S',
#  None,
#  None,
#  'A',
#  'S',
#  'L',
#  'E',
#  'E',
#  'P',
#  None,
#  'U',
#  'P',
#  'S',
#  'E',
#  'T',
#  None,
#  'G',
#  'M',
#  'C',
#  'L',
#  'A',
#  'I',
#  'D',
#  None,
#  'N',
#  'E',
#  'U',
#  'R',
#  'A',
#  'L',
#  None,
#  'N',
#  'O',
#  'O',
#  'N',
#  'E',
#  None,
#  'O',
#  'A',
#  'R',
#  'A',
#  'L',
#  'L',
#  'A',
#  None,
#  'N',
#  'E',
#  'V',
#  'E',
#  'R',
#  'E',
#  'N',
#  'D',
#  'I',
#  'N',
#  'G',
#  'S',
#  'T',
#  'O',
#  'R',
#  'Y',
#  'U',
#  'S',
#  'E',
#  'D',
#  'C',
#  'A',
#  'R',
#  None,
#  None,
#  None,
#  'U',
#  'A',
#  'E',
#  None,
#  None,
#  None,
#  'L',
#  'O',
#  'N',
#  'E',
#  None,
#  'S',
#  'A',
#  'N',
#  'S',
#  'A',
#  None,
#  None,
#  'B',
#  'E',
#  'A',
#  'R',
#  'S',
#  'R',
#  'E',
#  'P',
#  'E',
#  'A',
#  'T',
#  'I',
#  'N',
#  'G',
#  'E',
#  'M',
#  'T',
#  None,
#  'M',
#  'A',
#  'R',
#  'I',
#  'M',
#  'B',
#  'A',
#  None,
#  'D',
#  'R',
#  'A',
#  'G',
#  None,
#  'S',
#  'E',
#  'G',
#  'A',
#  None,
#  None,
#  'P',
#  'E',
#  'R',
#  'P',
#  'E',
#  'T',
#  'U',
#  'A',
#  'L',
#  'M',
#  'O',
#  'T',
#  'I',
#  'O',
#  'N',
#  None,
#  'S',
#  'O',
#  'Y',
#  None,
#  'K',
#  'A',
#  'N',
#  'Y',
#  'E',
#  'W',
#  'E',
#  'S',
#  'T',
#  None,
#  'A',
#  'G',
#  'E',
#  'N',
#  'T',
#  'S',
#  None,
#  None,
#  None,
#  None,
#  'F',
#  'A',
#  'R',
#  'M',
#  'S',
#  None,
#  None,
#  None,
#  None,
#  'E',
#  'O',
#  'S',
#  None,
#  None,
#  None,
#  None,
#  'A',
#  'S',
#  'P',
#  'C',
#  'A',
#  'E',
#  'T',
#  'T',
#  'A',
#  None,
#  'N',
#  'A',
#  'N',
#  'A',
#  None,
#  'P',
#  'O',
#  'P',
#  'A',
#  'R',
#  'T',
#  None,
#  'I',
#  'S',
#  'A',
#  'Y',
#  'T',
#  'A',
#  'N',
#  'S',
#  None,
#  'A',
#  'D',
#  'I',
#  'N',
#  'F',
#  'I',
#  'N',
#  'I',
#  'T',
#  'U',
#  'M',
#  None,
#  'K',
#  'E',
#  'R',
#  'R',
#  'I',
#  'N',
#  'E',
#  'S',
#  None,
#  'G',
#  'O',
#  'L',
#  'D',
#  'E',
#  'N',
#  None,
#  'G',
#  'E',
#  'E',
#  'Z',
#  None,
#  'H',
#  'U',
#  'M',
#  'E',
#  'D',
#  'A',
#  'R',
#  'E',
#  'I',
#  None,
#  None,
#  None,
#  None,
#  'W',
#  'E',
#  'D',
#  None,
#  None,
#  None,
#  None,
#  'T',
#  'I',
#  'D',
#  'E',
#  'S',
#  None,
#  None,
#  None,
#  None,
#  'S',
#  'H',
#  'A',
#  'R',
#  'P',
#  'E',
#  None,
#  'I',
#  'M',
#  'P',
#  'O',
#  'S',
#  'E',
#  'S',
#  'O',
#  'N',
#  None,
#  'N',
#  'B',
#  'C',
#  None,
#  'R',
#  'E',
#  'C',
#  'U',
#  'R',
#  'R',
#  'I',
#  'N',
#  'G',
#  'D',
#  'R',
#  'E',
#  'A',
#  'M',
#  'S',
#  None,
#  None,
#  'O',
#  'R',
#  'A',
#  'L',
#  None,
#  'R',
#  'A',
#  'F',
#  'E',
#  None,
#  'N',
#  'A',
#  'M',
#  'A',
#  'S',
#  'T',
#  'E',
#  None,
#  'C',
#  'I',
#  'T',
#  'N',
#  'O',
#  'N',
#  'S',
#  'T',
#  'O',
#  'P',
#  'F',
#  'L',
#  'I',
#  'G',
#  'H',
#  'T',
#  'S',
#  None,
#  None,
#  'G',
#  'U',
#  'I',
#  'D',
#  'O',
#  None,
#  'C',
#  'I',
#  'A',
#  'O',
#  None,
#  None,
#  None,
#  'A',
#  'C',
#  'R',
#  None,
#  None,
#  None,
#  'A',
#  'L',
#  'G',
#  'R',
#  'E',
#  'E',
#  'N',
#  'C',
#  'O',
#  'N',
#  'T',
#  'I',
#  'N',
#  'U',
#  'I',
#  'T',
#  'Y',
#  'O',
#  'F',
#  'C',
#  'A',
#  'R',
#  'E',
#  None,
#  'S',
#  'N',
#  'A',
#  'G',
#  'O',
#  'D',
#  'E',
#  None,
#  'L',
#  'E',
#  'T',
#  'M',
#  'E',
#  None,
#  'U',
#  'R',
#  'C',
#  'H',
#  'I',
#  'N',
#  None,
#  'A',
#  'C',
#  'L',
#  'U',
#  'Y',
#  'E',
#  'S',
#  None,
#  'S',
#  'T',
#  'E',
#  'P',
#  'S',
#  None,
#  'P',
#  'O',
#  'S',
#  'I',
#  'E',
#  'S',
#  None,
#  None,
#  'E',
#  'S',
#  'E']
