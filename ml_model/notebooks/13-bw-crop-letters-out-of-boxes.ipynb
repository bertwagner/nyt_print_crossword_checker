# %%
# %load_ext autoreload
# %autoreload 2
from src.util import utilities as u
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.data import image_proccessor as ip
import cv2
import datetime
import os

image_name = '2021-11-29-74a01658-af05-4544-9ab3-350f0759a1a0.png'
image_raw = cv2.imread(os.path.join("../data/raw/image_uploads",image_name))
date = datetime.datetime.strptime(image_name[0:10],'%Y-%m-%d').date()

processor = ip.ImageProcessor(image_raw)
processor.warp_and_transform()

u.showarray(processor.image['rgb'])
u.showarray(processor.image['warped'])
# Out:
# [autoreload of src.data.image_proccessor failed: Traceback (most recent call last):
#   File "/home/bert/miniconda3/envs/nyt_print_crossword_checker/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bert/miniconda3/envs/nyt_print_crossword_checker/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/bert/miniconda3/envs/nyt_print_crossword_checker/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/bert/miniconda3/envs/nyt_print_crossword_checker/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/bert/projects/nyt_print_crossword_checker/ml_model/src/data/image_proccessor.py", line 163
#     cropped_images.append(bw)
#                  ^
# SyntaxError: invalid syntax
# ]

# %%
processor.slice_up_grid()
for i,cell in enumerate(processor.image['cells'][:30]): # display only first several images
    u.showarray(cell)
    print(f"Cell {i} ++++++++++++++++++")
    for result in processor._ImageProcessor__crop_letters(cell):
        u.showarray(result)
        # for image in result:
        #     u.showarray(image)
    print("==============")
# Out:
# Cell 0 ++++++++++++++++++
# ==============
# Cell 1 ++++++++++++++++++
# ==============
# Cell 2 ++++++++++++++++++
# ==============
# Cell 3 ++++++++++++++++++
# ==============
# Cell 4 ++++++++++++++++++
# ==============
# Cell 5 ++++++++++++++++++
# ==============
# Cell 6 ++++++++++++++++++
# ==============
# Cell 7 ++++++++++++++++++
# ==============
# Cell 8 ++++++++++++++++++
# ==============
# Cell 9 ++++++++++++++++++
# ==============
# Cell 10 ++++++++++++++++++
# ==============
# Cell 11 ++++++++++++++++++
# ==============
# Cell 12 ++++++++++++++++++
# ==============
# Cell 13 ++++++++++++++++++
# ==============
# Cell 14 ++++++++++++++++++
# ==============
# Cell 15 ++++++++++++++++++
# ==============
# Cell 16 ++++++++++++++++++
# ==============
# Cell 17 ++++++++++++++++++
# ==============
# Cell 18 ++++++++++++++++++
# ==============
# Cell 19 ++++++++++++++++++
# ==============
# Cell 20 ++++++++++++++++++
# ==============
# Cell 21 ++++++++++++++++++
# ==============
# Cell 22 ++++++++++++++++++
# ==============
# Cell 23 ++++++++++++++++++
# ==============
# Cell 24 ++++++++++++++++++
# ==============
# Cell 25 ++++++++++++++++++
# ==============
# Cell 26 ++++++++++++++++++
# ==============
# Cell 27 ++++++++++++++++++
# ==============
# Cell 28 ++++++++++++++++++
# ==============
# Cell 29 ++++++++++++++++++
# ==============

# %%
""
